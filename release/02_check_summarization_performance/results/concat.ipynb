# %%
import os
import pandas as pd

# %%
p1 = '/home/wake/projects/local_llm/check_summarize_evalation/results/evaluation_summary_c4ai_command_r_plus_Q4_K_M.gguf.csv'
p2 = '/home/wake/projects/local_llm/check_summarize_evalation/results/evaluation_summary_cyberagent_calm3_22b_chat.csv'
p3 = '/home/wake/projects/local_llm/check_summarize_evalation/results/evaluation_summary_gpt_oss_20b_gguf.csv'
p4 = '/home/wake/projects/local_llm/check_summarize_evalation/results/evaluation_summary_qwen2_7b-instruct_q5_k_m_gguf.csv'

df1 = pd.read_csv(p1)
df2 = pd.read_csv(p2)
df3 = pd.read_csv(p3)
df4 = pd.read_csv(p4)

# %%
df = pd.concat([df1, df2, df3, df4])

# %%
path = '/home/wake/projects/local_llm/check_summarize_evalation/results/evaluation_summary.csv'
df.to_csv(path, index=False, encoding='utf-8')
